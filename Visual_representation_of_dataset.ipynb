# %%
import pandas as pd
import seaborn as sns
import warnings 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
warnings.filterwarnings('ignore')
dataset =pd.read_csv('clevedata.csv')

# %%
Age=dataset["age"]
plt.figure(figsize=(10,5))
plt.hist(Age, color = "blue" ,ec="black")
plt.title('AGE')
plt.show()

# %%
SEX=dataset["sex"]
plt.figure(figsize=(10,5))
plt.hist(SEX,color = "blue" ,ec="black")
plt.title('SEX')
plt.show()

# %%
Chest_pain=dataset["cp"]
plt.figure(figsize=(10,5))
plt.hist(Chest_pain,color = "red",ec="black")
plt.title('Chest pain')
plt.show()

# %%
Blood_pressure=dataset["trestbps"]
plt.figure(figsize=(10,5))
plt.hist(Blood_pressure, color = "red",ec="black")
plt.title('Blood Pressure')
plt.show()

# %%
Serum_cholesterol=dataset["chol"]
plt.figure(figsize=(10,5))
plt.hist(Serum_cholesterol, color = "green",ec="black")
plt.title('Cholesterol')
plt.show()

# %%
Fasting_blood_sugar=dataset["fbs"]
plt.figure(figsize=(10,5))
plt.hist(Fasting_blood_sugar, color = "green",ec="black")
plt.title('Fasting blood sugar')
plt.show()

# %%
Electrocardiographic=dataset["restecg"]
plt.figure(figsize=(10,5))
plt.hist(Electrocardiographic ,color = "blue" ,ec="black")
plt.title('Electrocardiographic')
plt.show()

# %%
Max_Heart_Rate=dataset["thalach"]
plt.figure(figsize=(10,5))
plt.hist(Max_Heart_Rate ,color = "blue" ,ec="black")
plt.title('Max Heart Rate')
plt.show()

# %%
Exercise_Induced_angina=dataset["exang"]

plt.figure(figsize=(10,5))
plt.hist(Exercise_Induced_angina,color = "red",ec="black")
plt.title('Exercise Induced angina')
plt.show()

# %%
ST_depression=dataset["oldpeak"]
plt.figure(figsize=(10,5))
plt.hist(ST_depression,color = "red",ec="black")
plt.title('ST depression')
plt.show()

# %%
Slope=dataset["slope"]
plt.figure(figsize=(10,5))
plt.hist(Slope, color = "green",ec="black")
plt.title('Slope')
plt.show()

# %%
Vessels=dataset["ca"]
plt.figure(figsize=(10,5))
plt.hist(Vessels, color = "green",ec="black")
plt.title('Vessels')
plt.show()

# %%
Thal=dataset["thal"]
plt.figure(figsize=(10,5))
plt.hist(Thal, color = "red",ec="black")
plt.title('Thal')
plt.show()

# %%
Diagnosis=dataset["num"]
plt.figure(figsize=(10,5))
plt.hist(Diagnosis,color = "red",ec="black")
plt.title('Diagnosis')
plt.show()

# %%
plt.boxplot(dataset["age"], boxprops=dict(color='red'))
plt.title('AGE')
# Out:
# Text(0.5, 1.0, 'AGE')

# %%
plt.boxplot(dataset["trestbps"], boxprops=dict(color='red'))
plt.title('Blood Pressure')
# Out:
# Text(0.5, 1.0, 'Blood Pressure')

# %%
plt.boxplot(dataset["chol"], boxprops=dict(color='red'))
plt.title('Cholesterol')
# Out:
# Text(0.5, 1.0, 'Cholesterol')

# %%
plt.boxplot(dataset["thalach"], boxprops=dict(color='red'))
plt.title('Max Heart Rate')
# Out:
# Text(0.5, 1.0, 'Max Heart Rate')

# %%
plt.boxplot(dataset["cp"], boxprops=dict(color='red'))
plt.title('Chest pain')
# Out:
# Text(0.5, 1.0, 'Chest pain')

# %%
plt.boxplot(dataset["oldpeak"], boxprops=dict(color='red'))
plt.title('ST depression')
# Out:
# Text(0.5, 1.0, 'ST depression')

# %%
plt.boxplot(dataset["slope"], boxprops=dict(color='red'))
plt.title('Slope')
# Out:
# Text(0.5, 1.0, 'Slope')
